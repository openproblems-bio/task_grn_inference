# %% [markdown]
# # task-perturb-multiomics-grn
# ## Creating resources
# ### by Jalil Nourisa

# %% [markdown]
# # Multiomics

# %%
import anndata as ad
import pandas as pd

import numpy as np
data_dir = '../../perturb-multiomics-grn/output/'

resource_dir = '../resources/grn-benchmark'
test_resource_dir = '../resources_test/grn-benchmark'

# %%
import anndata as ad 
import pandas as pd
import numpy as np
from scipy import sparse
import scanpy as sc
import requests

par = {
    'multiomics_rna': '../resources_test/grn-benchmark/multiomics_rna.h5ad',
    'multiomics_rna_test': 'resources_test/grn-benchmark/multiomics_rna.h5ad',

    'multiomics_atac': '../resources_test/grn-benchmark/multiomics_atac.h5ad',
    'multiomics_atac_test': 'resources_test/grn-benchmark/multiomics_atac.h5ad',

    'perturbation_data': 'resources/grn-benchmark/perturbation_data.h5ad',
    'perturbation_data_test': 'resources_test/grn-benchmark/perturbation_data.h5ad',
}

n_cells = 1000
n_peaks = 5000

adata_rna = ad.read_h5ad(par['multiomics_rna'])
adata_atac = ad.read_h5ad(par['multiomics_atac'])

# adata_rna.var.to_csv('../resources/grn-benchmark/supp/gene_location.csv')

# %%
obs = adata_rna.obs

cell_topic = pd.read_csv('../resources/grn-benchmark/supp/cell_topic.csv', index_col=0)
obs.index.isin(cell_topic.index)
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True])

# %%
import os 
adata_rna = ad.read_h5ad('../../../repo/_task-grn-benchmark/resources/grn-benchmark/multiomics_rna.h5ad')

# %%
gene_location = pd.read_csv('../resources/grn-benchmark/supp/gene_location.csv')
gene_location
# Out:
#          location         gene_ids                  interval
# 0      AL627309.1  ENSG00000238009        chr1:120931-133723
# 1      AL627309.5  ENSG00000241860        chr1:149706-173862
# 2      AL627309.4  ENSG00000241599        chr1:160445-160446
# 3       LINC01409  ENSG00000237491        chr1:778757-803934
# 4       LINC01128  ENSG00000228794        chr1:827597-860227
# ...           ...              ...                       ...
# 22782  AL354822.1  ENSG00000278384    GL000218.1:54892-54893
# 22783  AL592183.1  ENSG00000273748    GL000219.1:83310-83311
# 22784  AC240274.1  ENSG00000271254    KI270711.1:24649-29626
# 22785  AC004556.3  ENSG00000276345      KI270721.1:2584-2585
# 22786  AC007325.4  ENSG00000278817  KI270734.1:131493-131494
#
# [22787 rows x 3 columns]

# %%
# adata_rna.var = adata_rna.var.reset_index().merge(gene_location, on='location')
adata_rna.write('../../../repo/_task-grn-benchmark/resources/grn-benchmark/multiomics_rna.h5ad')

# %%
# shorten rna 
mask = adata_rna.obs.donor_id=='donor_0'
adata_rna_s = adata_rna[mask]
# only one chr and n_cells 
if 'interval' not in adata_rna.var:
    genenames = adata_rna_s.var_names
    location = [get_gene_location(gene_name) for gene_name in genenames]
    adata_rna_s.var['interval'] = location
chr_mask = adata_rna_s.var.interval.str.split(':').str[0] == 'chr1'
adata_rna_s = adata_rna_s[:n_cells, chr_mask]
# Out:
# A1BG
# A1BG-AS1
# A2M
# A2M-AS1
# A2ML1
# A2ML1-AS1
# A3GALT2
# A4GALT
# AAAS
# AACS
# AADACL2-AS1
# AAGAB
# AAK1
# AAMDC
# AAMP
# AANAT
# AAR2
# AARD
# AARS
# Bad request for gene: AARS. Check the gene name and try again.
# AARS2
# AARSD1
# AASDH
# AASDHPPT
# AASS
# AATBC
# AATF
# AATK
# ABALON
# ABAT
# ABCA1
# ABCA10
# ABCA12
# ABCA13
# ABCA2
# ABCA3
# ABCA4
# ABCA5
# ABCA6
# ABCA7
# ABCA8
# ABCA9
# ABCA9-AS1
# ABCB1
# ABCB10
# ABCB11
# ABCB4
# ABCB5
# ABCB6
# ABCB7
# ABCB8
# ABCB9
# ABCC1
# ABCC10
# ABCC11
# ABCC12
# ABCC2
# ABCC3
# ABCC4
# ABCC5
# ABCC5-AS1
# ABCC6
# ABCC9
# ABCD1
# ABCD2
# ABCD3
# ABCD4
# ABCE1
# ABCF1
# ABCF2
# ABCF3
# ABCG1
# ABCG2
# ABCG5
# ABCG8
# ABHD1
# ABHD10
# ABHD11
# ABHD12
# ABHD12B
# ABHD13
# ABHD14A
# ABHD14B
# ABHD15
# ABHD15-AS1
# ABHD16A
# ABHD17A
# ABHD17B
# ABHD17C
# ABHD18
# ABHD2
# ABHD3
# ABHD4
# ABHD5
# ABHD6
# ABHD8
# ABI1
# ABI2
# ABI3
# ABI3BP
# ABITRAM
# ABL1
# ABL2
# ABLIM1
# ABLIM2
# ABLIM3
# ABO
# ABR
# ABRA
# ABRACL
# ABRAXAS1
# ABRAXAS2
# ABT1
# ABTB1
# ABTB2
# AC000065.1
# Bad request for gene: AC000065.1. Check the gene name and try again.
# AC000065.2
# Bad request for gene: AC000065.2. Check the gene name and try again.
# AC000068.1
# Bad request for gene: AC000068.1. Check the gene name and try again.
# AC000085.1
# Bad request for gene: AC000085.1. Check the gene name and try again.
# AC000120.1
# Bad request for gene: AC000120.1. Check the gene name and try again.
# AC000403.1
# Bad request for gene: AC000403.1. Check the gene name and try again.
# AC002044.1
# Bad request for gene: AC002044.1. Check the gene name and try again.
# AC002066.1
# Bad request for gene: AC002066.1. Check the gene name and try again.
# AC002069.2
# Bad request for gene: AC002069.2. Check the gene name and try again.
# AC002070.1
# Bad request for gene: AC002070.1. Check the gene name and try again.
# AC002072.1
# Bad request for gene: AC002072.1. Check the gene name and try again.
# AC002074.1
# Bad request for gene: AC002074.1. Check the gene name and try again.
# AC002091.1
# Bad request for gene: AC002091.1. Check the gene name and try again.
# AC002091.2
# Bad request for gene: AC002091.2. Check the gene name and try again.
# AC002094.2
# Bad request for gene: AC002094.2. Check the gene name and try again.
# AC002094.4
# Bad request for gene: AC002094.4. Check the gene name and try again.
# AC002116.2
# Bad request for gene: AC002116.2. Check the gene name and try again.
# AC002128.1
# Bad request for gene: AC002128.1. Check the gene name and try again.
# AC002128.2
# Bad request for gene: AC002128.2. Check the gene name and try again.
# AC002306.1
# Bad request for gene: AC002306.1. Check the gene name and try again.
# AC002310.1
# Bad request for gene: AC002310.1. Check the gene name and try again.
# AC002310.2
# Bad request for gene: AC002310.2. Check the gene name and try again.
# AC002331.1
# Bad request for gene: AC002331.1. Check the gene name and try again.
# AC002347.1
# Bad request for gene: AC002347.1. Check the gene name and try again.
# AC002377.1
# Bad request for gene: AC002377.1. Check the gene name and try again.
# AC002383.1
# Bad request for gene: AC002383.1. Check the gene name and try again.
# AC002398.1
# Bad request for gene: AC002398.1. Check the gene name and try again.
# AC002401.1
# Bad request for gene: AC002401.1. Check the gene name and try again.
# AC002429.2
# Bad request for gene: AC002429.2. Check the gene name and try again.
# AC002451.1
# Bad request for gene: AC002451.1. Check the gene name and try again.
# AC002454.1
# Bad request for gene: AC002454.1. Check the gene name and try again.
# AC002456.1
# Bad request for gene: AC002456.1. Check the gene name and try again.
# AC002460.2
# Bad request for gene: AC002460.2. Check the gene name and try again.
# AC002463.1
# Bad request for gene: AC002463.1. Check the gene name and try again.
# AC002467.1
# Bad request for gene: AC002467.1. Check the gene name and try again.
# AC002470.1
# Bad request for gene: AC002470.1. Check the gene name and try again.
# AC002480.2
# Bad request for gene: AC002480.2. Check the gene name and try again.
# AC002546.1
# Bad request for gene: AC002546.1. Check the gene name and try again.
# AC002550.1
# Bad request for gene: AC002550.1. Check the gene name and try again.
# AC002550.2
# Bad request for gene: AC002550.2. Check the gene name and try again.
# AC002551.1
# Bad request for gene: AC002551.1. Check the gene name and try again.
# AC002553.1
# Bad request for gene: AC002553.1. Check the gene name and try again.
# AC002553.2
# Bad request for gene: AC002553.2. Check the gene name and try again.
# AC002558.2
# Bad request for gene: AC002558.2. Check the gene name and try again.
# AC002558.3
# Bad request for gene: AC002558.3. Check the gene name and try again.
# AC003005.2
# Bad request for gene: AC003005.2. Check the gene name and try again.
# AC003035.1
# Bad request for gene: AC003035.1. Check the gene name and try again.
# AC003043.2
# Bad request for gene: AC003043.2. Check the gene name and try again.
# AC003077.1
# Bad request for gene: AC003077.1. Check the gene name and try again.
# AC003092.1
# Bad request for gene: AC003092.1. Check the gene name and try again.
# AC003093.1
# Bad request for gene: AC003093.1. Check the gene name and try again.
# AC003102.1
# Bad request for gene: AC003102.1. Check the gene name and try again.
# AC003681.1
# Bad request for gene: AC003681.1. Check the gene name and try again.
# AC003682.1
# Bad request for gene: AC003682.1. Check the gene name and try again.
# AC003684.1
# Bad request for gene: AC003684.1. Check the gene name and try again.
# AC003965.2
# Bad request for gene: AC003965.2. Check the gene name and try again.
# AC003991.1
# Bad request for gene: AC003991.1. Check the gene name and try again.
# AC003991.2
# Bad request for gene: AC003991.2. Check the gene name and try again.
# AC004000.1
# Bad request for gene: AC004000.1. Check the gene name and try again.
# AC004034.1
# Bad request for gene: AC004034.1. Check the gene name and try again.
# AC004039.1
# Bad request for gene: AC004039.1. Check the gene name and try again.
# AC004053.1
# Bad request for gene: AC004053.1. Check the gene name and try again.
# AC004067.1
# Bad request for gene: AC004067.1. Check the gene name and try again.
# AC004069.1
# Bad request for gene: AC004069.1. Check the gene name and try again.
# AC004076.2
# Bad request for gene: AC004076.2. Check the gene name and try again.
# AC004083.1
# Bad request for gene: AC004083.1. Check the gene name and try again.
# AC004112.1
# Bad request for gene: AC004112.1. Check the gene name and try again.
# AC004148.1
# Bad request for gene: AC004148.1. Check the gene name and try again.
# AC004158.1
# Bad request for gene: AC004158.1. Check the gene name and try again.
# AC004160.1
# Bad request for gene: AC004160.1. Check the gene name and try again.
# AC004217.1
# Bad request for gene: AC004217.1. Check the gene name and try again.
# AC004223.2
# Bad request for gene: AC004223.2. Check the gene name and try again.
# AC004223.4
# Bad request for gene: AC004223.4. Check the gene name and try again.
# AC004231.1
# Bad request for gene: AC004231.1. Check the gene name and try again.
# AC004232.1
# Bad request for gene: AC004232.1. Check the gene name and try again.
# AC004233.3
# Bad request for gene: AC004233.3. Check the gene name and try again.
# AC004241.1
# Bad request for gene: AC004241.1. Check the gene name and try again.
# AC004241.3
# Bad request for gene: AC004241.3. Check the gene name and try again.
# AC004253.1
# Bad request for gene: AC004253.1. Check the gene name and try again.
# AC004257.1
# Bad request for gene: AC004257.1. Check the gene name and try again.
# AC004263.2
# Bad request for gene: AC004263.2. Check the gene name and try again.
# AC004381.1
# Bad request for gene: AC004381.1. Check the gene name and try again.
# AC004448.2
# Bad request for gene: AC004448.2. Check the gene name and try again.
# AC004461.2
# Bad request for gene: AC004461.2. Check the gene name and try again.
# AC004466.1
# Bad request for gene: AC004466.1. Check the gene name and try again.
# AC004466.2
# Bad request for gene: AC004466.2. Check the gene name and try again.
# AC004471.1
# Bad request for gene: AC004471.1. Check the gene name and try again.
# AC004477.1
# Bad request for gene: AC004477.1. Check the gene name and try again.
# AC004485.1
# Bad request for gene: AC004485.1. Check the gene name and try again.
# AC004490.1
# Bad request for gene: AC004490.1. Check the gene name and try again.
# AC004492.1
# Bad request for gene: AC004492.1. Check the gene name and try again.
# AC004494.1
# Bad request for gene: AC004494.1. Check the gene name and try again.
# AC004522.5
# Bad request for gene: AC004522.5. Check the gene name and try again.
# AC004528.1
# Bad request for gene: AC004528.1. Check the gene name and try again.
# AC004528.2
# Bad request for gene: AC004528.2. Check the gene name and try again.
# AC004540.1
# Bad request for gene: AC004540.1. Check the gene name and try again.
# AC004540.2
# Bad request for gene: AC004540.2. Check the gene name and try again.
# AC004542.2
# Bad request for gene: AC004542.2. Check the gene name and try again.
# AC004551.1
# Bad request for gene: AC004551.1. Check the gene name and try again.
# AC004554.2
# Bad request for gene: AC004554.2. Check the gene name and try again.
# AC004556.3
# Bad request for gene: AC004556.3. Check the gene name and try again.
# AC004584.1
# Bad request for gene: AC004584.1. Check the gene name and try again.
# AC004584.3
# Bad request for gene: AC004584.3. Check the gene name and try again.
# AC004585.1
# Bad request for gene: AC004585.1. Check the gene name and try again.
# AC004593.1
# Bad request for gene: AC004593.1. Check the gene name and try again.
# AC004593.3
# Bad request for gene: AC004593.3. Check the gene name and try again.
# AC004594.1
# Bad request for gene: AC004594.1. Check the gene name and try again.
# AC004596.1
# Bad request for gene: AC004596.1. Check the gene name and try again.
# AC004672.1
# Bad request for gene: AC004672.1. Check the gene name and try again.
# AC004687.1
# Bad request for gene: AC004687.1. Check the gene name and try again.
# AC004702.1
# Bad request for gene: AC004702.1. Check the gene name and try again.
# AC004704.1
# Bad request for gene: AC004704.1. Check the gene name and try again.
# AC004706.1
# Bad request for gene: AC004706.1. Check the gene name and try again.
# AC004765.1
# Bad request for gene: AC004765.1. Check the gene name and try again.
# AC004771.1
# Bad request for gene: AC004771.1. Check the gene name and try again.
# AC004771.3
# Bad request for gene: AC004771.3. Check the gene name and try again.
# AC004771.4
# Bad request for gene: AC004771.4. Check the gene name and try again.
# AC004784.1
# Bad request for gene: AC004784.1. Check the gene name and try again.
# AC004797.1
# Bad request for gene: AC004797.1. Check the gene name and try again.
# AC004801.4
# Bad request for gene: AC004801.4. Check the gene name and try again.
# AC004801.6
# Bad request for gene: AC004801.6. Check the gene name and try again.
# AC004803.1
# Bad request for gene: AC004803.1. Check the gene name and try again.
# AC004812.2
# Bad request for gene: AC004812.2. Check the gene name and try again.
# AC004816.1
# Bad request for gene: AC004816.1. Check the gene name and try again.
# AC004817.3
# Bad request for gene: AC004817.3. Check the gene name and try again.
# AC004817.5
# Bad request for gene: AC004817.5. Check the gene name and try again.
# AC004825.2
# Bad request for gene: AC004825.2. Check the gene name and try again.
# AC004825.3
# Bad request for gene: AC004825.3. Check the gene name and try again.
# AC004828.2
# Bad request for gene: AC004828.2. Check the gene name and try again.
# AC004830.2
# Bad request for gene: AC004830.2. Check the gene name and try again.
# AC004832.4
# Bad request for gene: AC004832.4. Check the gene name and try again.
# AC004834.1
# Bad request for gene: AC004834.1. Check the gene name and try again.
# AC004837.2
# Bad request for gene: AC004837.2. Check the gene name and try again.
# AC004837.4
# Bad request for gene: AC004837.4. Check the gene name and try again.
# AC004839.2
# Bad request for gene: AC004839.2. Check the gene name and try again.
# AC004846.1
# Bad request for gene: AC004846.1. Check the gene name and try again.
# AC004846.2
# Bad request for gene: AC004846.2. Check the gene name and try again.
# AC004847.1
# Bad request for gene: AC004847.1. Check the gene name and try again.
# AC004854.2
# Bad request for gene: AC004854.2. Check the gene name and try again.
# AC004865.2
# Bad request for gene: AC004865.2. Check the gene name and try again.
# AC004877.1
# Bad request for gene: AC004877.1. Check the gene name and try again.
# AC004884.2
# Bad request for gene: AC004884.2. Check the gene name and try again.
# AC004889.1
# Bad request for gene: AC004889.1. Check the gene name and try again.
# AC004893.3
# Bad request for gene: AC004893.3. Check the gene name and try again.
# AC004900.1
# Bad request for gene: AC004900.1. Check the gene name and try again.
# AC004906.1
# Bad request for gene: AC004906.1. Check the gene name and try again.
# AC004908.2
# Bad request for gene: AC004908.2. Check the gene name and try again.
# AC004908.3
# Bad request for gene: AC004908.3. Check the gene name and try again.
# AC004917.1
# Bad request for gene: AC004917.1. Check the gene name and try again.
# AC004918.1
# Bad request for gene: AC004918.1. Check the gene name and try again.
# AC004918.4
# Bad request for gene: AC004918.4. Check the gene name and try again.
# AC004921.1
# Bad request for gene: AC004921.1. Check the gene name and try again.
# AC004921.2
# Bad request for gene: AC004921.2. Check the gene name and try again.
# AC004923.4
# Bad request for gene: AC004923.4. Check the gene name and try again.
# AC004938.2
# Bad request for gene: AC004938.2. Check the gene name and try again.
# AC004943.2
# Bad request for gene: AC004943.2. Check the gene name and try again.
# AC004947.3
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 25
#      23 if 'interval' not in adata_rna.var:
#      24     genenames = adata_rna_s.var_names
# ---> 25     location = [get_gene_location(gene_name) for gene_name in genenames]
#      26     adata_rna_s.var['interval'] = location
#      27 chr_mask = adata_rna_s.var.interval.str.split(':').str[0] == 'chr1'
#
# Cell In[3], line 25, in <listcomp>(.0)
#      23 if 'interval' not in adata_rna.var:
#      24     genenames = adata_rna_s.var_names
# ---> 25     location = [get_gene_location(gene_name) for gene_name in genenames]
#      26     adata_rna_s.var['interval'] = location
#      27 chr_mask = adata_rna_s.var.interval.str.split(':').str[0] == 'chr1'
#
# Cell In[3], line 6, in get_gene_location(gene_name)
#       4 server = "https://rest.ensembl.org"
#       5 ext = f"/lookup/symbol/homo_sapiens/{gene_name}?content-type=application/json"
# ----> 6 r = requests.get(server + ext)
#       7 if r.status_code == 400:
#       8     print(f"Bad request for gene: {gene_name}. Check the gene name and try again.")
#
# File ~/anaconda3/envs/py10/lib/python3.10/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/anaconda3/envs/py10/lib/python3.10/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/anaconda3/envs/py10/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/py10/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/anaconda3/envs/py10/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/anaconda3/envs/py10/lib/python3.10/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~/anaconda3/envs/py10/lib/python3.10/site-packages/urllib3/connectionpool.py:466, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
#     464     # Trigger any extra validation we need to do.
#     465     try:
# --> 466         self._validate_conn(conn)
#     467     except (SocketTimeout, BaseSSLError) as e:
#     468         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File ~/anaconda3/envs/py10/lib/python3.10/site-packages/urllib3/connectionpool.py:1095, in HTTPSConnectionPool._validate_conn(self, conn)
#    1093 # Force connect early to allow us to validate the connection.
#    1094 if conn.is_closed:
# -> 1095     conn.connect()
#    1097 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#    1098 if not conn.is_verified and not conn.proxy_is_verified:
#
# File ~/anaconda3/envs/py10/lib/python3.10/site-packages/urllib3/connection.py:615, in HTTPSConnection.connect(self)
#     613 def connect(self) -> None:
#     614     sock: socket.socket | ssl.SSLSocket
# --> 615     self.sock = sock = self._new_conn()
#     616     server_hostname: str = self.host
#     617     tls_in_tls = False
#
# File ~/anaconda3/envs/py10/lib/python3.10/site-packages/urllib3/connection.py:196, in HTTPConnection._new_conn(self)
#     191 """Establish a socket connection and set nodelay settings on it.
#     192
#     193 :return: New socket connection.
#     194 """
#     195 try:
# --> 196     sock = connection.create_connection(
#     197         (self._dns_host, self.port),
#     198         self.timeout,
#     199         source_address=self.source_address,
#     200         socket_options=self.socket_options,
#     201     )
#     202 except socket.gaierror as e:
#     203     raise NameResolutionError(self.host, self, e) from e
#
# File ~/anaconda3/envs/py10/lib/python3.10/site-packages/urllib3/util/connection.py:60, in create_connection(address, timeout, source_address, socket_options)
#      57 except UnicodeError:
#      58     raise LocationParseError(f"'{host}', label empty or too long") from None
# ---> 60 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      61     af, socktype, proto, canonname, sa = res
#      62     sock = None
#
# File ~/anaconda3/envs/py10/lib/python3.10/socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     952 # We override this function since we want to translate the numeric family
#     953 # and socket type values to enum constants.
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#     957     addrlist.append((_intenum_converter(af, AddressFamily),
#     958                      _intenum_converter(socktype, SocketKind),
#     959                      proto, canonname, sa))
#
# KeyboardInterrupt:

# %% [markdown]
# # Prior

# %% [markdown]
# ## tf names

# %%
prior_adata = ad.AnnData()

# %%
# tfs list 
tf_list = np.loadtxt("https://resources.aertslab.org/cistarget/tf_lists/allTFs_hg38.txt", dtype=str)
prior_adata.uns['tf_list'] = tf_list

# %% [markdown]
# ## gene names

# %%
bulk_adata = ad.read_h5ad(f'{resource_dir}/perturbation_data.h5ad')
prior_adata.uns['gene_names_pert'] = bulk_adata.var_names.to_numpy()

# %%
bulk_adata = ad.read_h5ad(f'{resource_dir}/multiomics_rna.h5ad')
prior_adata.uns['gene_names'] = bulk_adata.var_names.to_numpy()

# %%
bulk_adata = ad.read_h5ad(f'{resource_dir}/multiomics_atac.h5ad')
prior_adata.uns['peak'] = bulk_adata.var_names.to_numpy()

# %%
prior_adata.uns['hvgs'] = np.loadtxt(f'{resource_dir}/hvgs.txt', dtype=str)

# %%
prior_adata.write(f'{resource_dir}/prior_data.h5ad')

# %% [markdown]
# ## Gene names

# %%
np.savetxt(f'{work_dir}/benchmark/perturb_gene_names.txt', bulk_adata.var_names.values  , fmt='%s')

# %%
import requests

url = "https://ftp.ebi.ac.uk/pub/databases/gencode/Gencode_human/release_46/gencode.v46.annotation.gtf.gz"
local_filename = "gencode.v46.annotation.gtf.gz"

with requests.get(url, stream=True) as r:
    r.raise_for_status()
    with open(local_filename, 'wb') as f:
        for chunk in r.iter_content(chunk_size=8192):
            f.write(chunk)

# %% [markdown]
# ## HVGs

# %%
n_hvgs = 3000

# %%
# %load_ext rpy2.ipython

# %%
# %%R -i work_dir
# library(scry)
# library(zellkonverter)
# library(SingleCellExperiment)
# options(digits=5, max.print=100)  # Adjust numbers as needed
#
#
#
# adata = readH5AD(paste0(work_dir, "/preprocess/bulk_adata_f.h5ad")) # raw counts
# sce = devianceFeatureSelection(adata, assay="X", batch=colData(adata)$plate_name)
# writeH5AD(sce, paste0(work_dir, "/preprocess/adata_sce.h5ad"))
# Out:
#     WARNING: The R package "reticulate" only fixed recently
#     an issue that caused a segfault when used with rpy2:
#     https://github.com/rstudio/reticulate/pull/1188
#     Make sure that you use a version of that package that includes
#     the fix.
# /root/anaconda3/envs/py10/lib/python3.10/site-packages/rpy2/rinterface.py:186: FutureWarning: Index.format is deprecated and will be removed in a future version. Convert using index.astype(str) or index.map(formatter) instead.
#   openrlib.rlib.R_tryEval(
# /root/.cache/R/basilisk/1.14.3/zellkonverter/1.12.1/zellkonverterAnnDataEnv-0.10.2/lib/python3.11/site-packages/anndata/_core/anndata.py:522: FutureWarning: The dtype argument is deprecated and will be removed in late 2024.
#   warnings.warn(
# Registered S3 methods overwritten by 'zellkonverter':
#   method                                             from
#   py_to_r.numpy.ndarray                              reticulate
#   py_to_r.pandas.core.arrays.categorical.Categorical reticulate
# Loading required package: SummarizedExperiment
# Loading required package: MatrixGenerics
# Loading required package: matrixStats
#
# Attaching package: ‘MatrixGenerics’
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
# Loading required package: GenomicRanges
# Loading required package: stats4
# Loading required package: BiocGenerics
#
# Attaching package: ‘BiocGenerics’
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, sort,
#     table, tapply, union, unique, unsplit, which.max, which.min
#
# Loading required package: S4Vectors
#
# Attaching package: ‘S4Vectors’
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
# Loading required package: IRanges
# Loading required package: GenomeInfoDb
# Loading required package: Biobase
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# Attaching package: ‘Biobase’
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
# In addition: Warning messages:
# 1: In (function (package, help, pos = 2, lib.loc = NULL, character.only = FALSE,  :
#   library ‘/usr/lib/R/site-library’ contains no packages
# 2: Python '/root/.cache/R/basilisk/1.14.3/zellkonverter/1.12.1/zellkonverterAnnDataEnv-0.10.2/bin/python' was requested but '/root/anaconda3/envs/py10/bin/python' was loaded instead (see reticulate::py_config() for more information)

# %%
adata_sce = ad.read(f"{work_dir}/preprocess/adata_sce.h5ad")
binomial_deviance  = adata_sce.var['binomial_deviance']
# Out:
# /root/anaconda3/envs/py10/lib/python3.10/site-packages/anndata/__init__.py:55: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.
#   warnings.warn(

# %%
adata_sce.var['binomial_deviance']
# Out:
# A1BG         3242.560255
# A1BG-AS1     3081.247245
# A2M         51924.570033
# A2M-AS1     47137.741205
# A2MP1        4798.622262
#                 ...
# ZXDB         3123.833965
# ZXDC         2762.431522
# ZYG11B      14322.309802
# ZYX         60193.206178
# ZZEF1        5337.865927
# Name: binomial_deviance, Length: 15215, dtype: float64

# %%
indices = binomial_deviance.argsort()[-n_hvgs:]
mask = np.zeros(adata_sce.var.shape[0], dtype=bool)
mask[indices] = True
hvgs_sce = adata_sce[:, mask].var.index.values

# %%
np.savetxt( f'{work_dir}/benchmark/hvgs.txt',hvgs_sce, fmt='%s')

# %% [markdown]
# ## Gene annotation

# %%
# load the annotations and subset it for genes in multiomics data. also, remove
from local_utils import annotation

multiomics_genes =  np.loadtxt(f'{work_dir}/benchmark/multiomics_genes.txt', dtype=str)
annot_database = annotation.ensembl_gene_annotation()

transcript_types = ['protein_coding', 'lncRNA', 'miRNA']

annot_database_f = annot_database[annot_database.Gene.isin(multiomics_genes)].reset_index()

annot_database_f = annot_database_f[['Gene', 'Transcript_type']].drop_duplicates()
annot_database_f = annot_database_f[annot_database_f.Transcript_type.isin(transcript_types)]
rename_map = {'protein_coding':'Protein coding', 'lncRNA':'LncRNA',  'miRNA':'MicroRNA'}
annot_database_f.Transcript_type = annot_database_f.Transcript_type.map(rename_map)
annot_database_f.reset_index(drop=True, inplace=True)
annot_database_f.head()
# Out:
#          Gene Transcript_type
# 0  AC007325.4  Protein coding
# 1  AC107375.1          LncRNA
# 2  AC022306.3          LncRNA
# 3       ALDOC  Protein coding
# 4       HEMK1  Protein coding

# %%
 #only keep genes with one annotation
annot_size = annot_database_f.groupby('Gene').size()
kept_genes = annot_size[~(annot_size>1)].index
annot_database_f = annot_database_f[annot_database_f.Gene.isin(kept_genes)].reset_index(drop=True)
annot_database_f.shape
# Out:
# (22139, 2)

# %%
annot_database_f.Transcript_type.value_counts()
# Out:
# Transcript_type
# Protein coding    15282
# LncRNA             6856
# MicroRNA              1
# Name: count, dtype: int64

# %%
#save 
annot_database_f.to_csv(f'{work_dir}/benchmark/gene_annotation.csv')

# %% [markdown]
# ## peak annotation

# %%
adata_atac = ad.read_h5ad(f'{work_dir}/scATAC/adata_atac.h5ad')
# Out:
# /root/anaconda3/envs/py10/lib/python3.10/site-packages/anndata/_core/aligned_df.py:67: ImplicitModificationWarning: Transforming to str index.
#   warnings.warn("Transforming to str index.", ImplicitModificationWarning)

# %%
## check if all the peaks in grns given in atac data
import re

def format_peak(peaks):
    formatted_peaks = []
    for peak in peaks:
        chr_, start, end = re.split(r'[:\-_]', peak)
        peak = f"{chr_}:{start}-{end}"

        formatted_peaks.append(peak)
    return formatted_peaks


atac_peaks = format_peak(adata_atac.var_names)

# %%
peaks = pd.DataFrame({'chr':[peak.split(':')[0] for peak in atac_peaks],
                                     'range':[peak.split(':')[1] for peak in atac_peaks]})
peaks
# Out:
#           chr                range
# 0       chr10  100001032-100001800
# 1       chr10  100006075-100006963
# 2       chr10  100009475-100010367
# 3       chr10  100013993-100014884
# 4       chr10  100020278-100021136
# ...       ...                  ...
# 135353   chrY      7765105-7765991
# 135354   chrY      7814158-7815060
# 135355   chrY      7818681-7819599
# 135356   chrY      8535565-8536421
# 135357   chrY      8537529-8538370
#
# [135358 rows x 2 columns]

# %%
# %%R -i peaks -o peaks_annotated_df
# options(digits=5, max.print=100)  # Adjust numbers as needed
# set.seed(123)
#
# # install.packages("IRanges")
# # install.packages("GenomicRanges")
# # install.packages("ggplot2")
# # install.packages("TxDb.Hsapiens.UCSC.hg38.knownGene")
#
# library(IRanges)
# library(GenomicRanges)
# library(ggplot2)
# library(TxDb.Hsapiens.UCSC.hg38.knownGene)
#
# txdb <- TxDb.Hsapiens.UCSC.hg38.knownGene
#
#
# peaks = GRanges(peaks$chr, IRanges(peaks$range))
# peaks_annotated = suppressMessages(ChIPseeker::annotatePeak(
#     peaks,
#     tssRegion = c(-1000, 1000), # extended from -5kb to 5
#     TxDb = txdb,
#     level = "transcript",
#     assignGenomicAnnotation = TRUE,  # the default
#     genomicAnnotationPriority = c("Promoter", "5UTR", "3UTR", "Exon", "Intron",
#                                 "Downstream", "Intergenic"),  # the default
#     annoDb = NULL,
#     sameStrand = FALSE, # the default
#     ignoreOverlap = FALSE, # the default
#     ignoreUpstream = FALSE, # the default
#     ignoreDownstream = FALSE, # the default
#     overlap = "TSS", # the default
#     verbose = TRUE # the default
# ))
# peaks_annotated_df = as.data.frame(peaks_annotated)
# # write.table(peaks_annotated_df, paste0(temp_dir, name, '_annot.txt'), sep=',', row.names = FALSE)
# Out:
# >> preparing features information...		 2024-06-18 14:17:45
# >> identifying nearest features...		 2024-06-18 14:17:46
# >> calculating distance from peak to TSS...	 2024-06-18 14:17:48
# >> assigning genomic annotation...		 2024-06-18 14:17:48
# >> assigning chromosome lengths			 2024-06-18 14:18:10
# >> done...					 2024-06-18 14:18:10
# Loading required package: GenomicFeatures
# Loading required package: AnnotationDbi

# %%
peaks_annotated_df.head()
# Out:
#   seqnames      start        end  width strand  \
# 1    chr10  100001032  100001800    769      *
# 2    chr10  100006075  100006963    889      *
# 3    chr10  100009475  100010367    893      *
# 4    chr10  100013993  100014884    892      *
# 5    chr10  100020278  100021136    859      *
#
#                                          annotation  geneChr  geneStart  \
# 1  Intron (ENST00000324109.9/23268, intron 1 of 16)       10   99875577
# 2  Intron (ENST00000324109.9/23268, intron 1 of 16)       10   99875577
# 3                                          Promoter       10   99875577
# 4                                 Distal Intergenic       10   99875577
# 5                                 Distal Intergenic       10   99875577
#
#      geneEnd  geneLength  geneStrand geneId       transcriptId  distanceToTSS
# 1  100009947      134371           2  23268  ENST00000324109.9         8147.0
# 2  100009947      134371           2  23268  ENST00000324109.9         2984.0
# 3  100009947      134371           2  23268  ENST00000324109.9            0.0
# 4  100009947      134371           2  23268  ENST00000324109.9        -4046.0
# 5  100009947      134371           2  23268  ENST00000324109.9       -10331.0

# %%
map_={'Intron':'Intron', 'Exon':'Exon', 'Promoter':'Promoter', 'Distal':'Distal Intergenic', "3'":"3' UTR", 'Downstream':'Downstream (<=300)', "5'":"5' UTR"}

ann = peaks_annotated_df.annotation.str.split(' ', expand=True)[0]
ann = ann.map(map_)
peaks = peaks_annotated_df['seqnames'].astype(str)+':'+peaks_annotated_df['start'].astype(str) +'-' + peaks_annotated_df['end'].astype(str)
df = pd.DataFrame({'annotation':ann, 'peak':peaks})
df.to_csv(f'{resource_dir}/benchmark/peak_annotation.csv')
